# %%
import pandas as pd

# %% [markdown]
# # Euro 2012 (10 points)

# %% [markdown]
# Import Euro 2012 team stats dataset from `Euro_2012.csv`
#
# Note: please upload `Euro_2012.csv` file using File Explorer tool on your left
#
# ![image.png](data:image/png;base64,...)

# %%
euro_stats = pd.read_csv('Euro_2012.csv')

# %%
euro_stats
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 3              50.0%            17.2%                          40
# 4              37.9%             6.5%                          65
# 5              47.8%            15.6%                          80
# 6              30.7%            19.2%                          32
# 7              43.0%             7.5%                         110
# 8              25.0%             4.1%                          60
# 9              39.4%             5.2%                          48
# 10             34.3%             9.3%                          82
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored  ...  Saves made  \
# 0              0              0                     0  ...          13
# 1              0              0                     0  ...           9
# 2              1              0                     0  ...          10
# 3              0              0                     0  ...          22
# 4              1              0                     0  ...           6
# 5              2              1                     0  ...          10
# 6              1              1                     1  ...          13
# 7              2              0                     0  ...          20
# 8              2              0                     0  ...          12
# 9              0              0                     0  ...           6
# 10             6              0                     0  ...          10
# 11             0              0                     0  ...          17
# 12             2              0                     0  ...          10
# 13             0              1                     0  ...          15
# 14             3              0                     0  ...           8
# 15             0              0                     0  ...          13
#
#     Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  Yellow Cards  \
# 0                  81.3%         41             62         2             9
# 1                  60.1%         53             73         8             7
# 2                  66.7%         25             38         8             4
# 3                  88.1%         43             45         6             5
# 4                  54.6%         36             51         5             6
# 5                  62.6%         63             49        12             4
# 6                  65.1%         67             48        12             9
# 7                  74.1%        101             89        16            16
# 8                  70.6%         35             30         3             5
# 9                  66.7%         48             56         3             7
# 10                 71.5%         73             90        10            12
# 11                 65.4%         43             51        11             6
# 12                 77.0%         34             43         4             6
# 13                 93.8%        102             83        19            11
# 14                 61.6%         35             51         7             7
# 15                 76.5%         48             31         4             5
#
#     Red Cards  Subs on  Subs off  Players Used
# 0           0        9         9            16
# 1           0       11        11            19
# 2           0        7         7            15
# 3           0       11        11            16
# 4           0       11        11            19
# 5           0       15        15            17
# 6           1       12        12            20
# 7           0       18        18            19
# 8           0        7         7            15
# 9           1        7         7            17
# 10          0       14        14            16
# 11          1       10        10            17
# 12          0        7         7            16
# 13          0       17        17            18
# 14          0        9         9            18
# 15          0        9         9            18
#
# [16 rows x 35 columns]

# %% [markdown]
# Get the number of teams participated in the Euro2012?

# %%
euro_stats.Team.count()
# Out:
# 16

# %% [markdown]
# List all the columns in the dataset using `info()`

# %%
euro_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
#  13  Passing Accuracy            16 non-null     object
#  14  Touches                     16 non-null     int64
#  15  Crosses                     16 non-null     int64
#  16  Dribbles                    16 non-null     int64
#  17  Corners Taken               16 non-null     int64
#  18  Tackles                     16 non-null     int64
#  19  Clearances                  16 non-null     int64
#  20  Interceptions               16 non-null     int64
#  21  Clearances off line         15 non-null     float64
#  22  Clean Sheets                16 non-null     int64
#  23  Blocks                      16 non-null     int64
#  24  Goals conceded              16 non-null     int64
#  25  Saves made                  16 non-null     int64
#  26  Saves-to-shots ratio        16 non-null     object
#  27  Fouls Won                   16 non-null     int64
#  28  Fouls Conceded              16 non-null     int64
#  29  Offsides                    16 non-null     int64
#  30  Yellow Cards                16 non-null     int64
#  31  Red Cards                   16 non-null     int64
#  32  Subs on                     16 non-null     int64
#  33  Subs off                    16 non-null     int64
#  34  Players Used                16 non-null     int64
# dtypes: float64(1), int64(29), object(5)
# memory usage: 4.5+ KB

# %% [markdown]
# Create a DataFrame `discipline` consisting of Team, Yellow Cards, Red Cards columns

# %%
discipline = euro_stats[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Sort the teams by Red Cards, then Yellow Cards in descending order

# %%
discipline.sort_values(by=['Red Cards', 'Yellow Cards'], ascending=False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# Compute the average number of Yellow Cards given per Team

# %%
discipline['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# Show a DataFrame of teams that scored more than 6 goals

# %%
euro_stats[euro_stats.Goals > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# [2 rows x 35 columns]

# %% [markdown]
# Show a DataFrame of teams that start with letter C
#
# Hint: `str.startswith()`

# %%
euro_stats[euro_stats.Team.str.startswith('C')]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 0                     0  ...          13                 81.3%         41
# 1                     0  ...           9                 60.1%         53
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 0             62         2             9          0        9         9
# 1             73         8             7          0       11        11
#
#    Players Used
# 0            16
# 1            19
#
# [2 rows x 35 columns]

# %% [markdown]
# Show the first 6 columns of the original DataFrame
#
# Hint: `.iloc()`

# %%
euro_stats.iloc[:, :6]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots
# 0              51.9%            16.0%
# 1              41.9%            12.9%
# 2              50.0%            20.0%
# 3              50.0%            17.2%
# 4              37.9%             6.5%
# 5              47.8%            15.6%
# 6              30.7%            19.2%
# 7              43.0%             7.5%
# 8              25.0%             4.1%
# 9              39.4%             5.2%
# 10             34.3%             9.3%
# 11             36.8%             5.2%
# 12             22.5%            12.5%
# 13             55.9%            16.0%
# 14             47.2%            13.8%
# 15             21.2%             6.0%

# %% [markdown]
# Show a DataFrame containing Shooting Accuracy from Greece, Germany and Sweden
#
# Hint: slice the original DataFrame by labels using `.loc()`

# %%
euro_stats.loc[[6, 5, 14], ['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 6    Greece             30.7%
# 5   Germany             47.8%
# 14   Sweden             47.2%

# %% [markdown]
# # Alcohol Consumption (5 points)

# %% [markdown]
# Import dataset from `alcohol.csv`

# %%
alcohol = pd.read_csv('alcohol.csv')

# %%
alcohol
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# ..                            ...       ...
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %% [markdown]
# Which continent drinks more beer on average? List average beer consumption per continent.

# %%
alcohol_continent = alcohol.groupby('continent')
alcohol_continent.beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %% [markdown]
# For each continent, `describe()` the statistics for wine consumption.

# %%
alcohol_continent['wine_servings'].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# Show the mean alcohol consumption per continent for every alcohol type using the DataFrame layout below.
#
# ![image.png](data:image/png;base64,...)

# %%
alcohol_continent.mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %% [markdown]
# Show the mean, min and max values for spirit consumption using the DataFrame layout below.
#
# ![image.png](data:image/png;base64,...)

# %%
alcohol_continent.spirit_servings.describe()[['mean', 'min', 'max']]
# Out:
#                  mean   min    max
# continent
# AF          16.339623   0.0  152.0
# AS          60.840909   0.0  326.0
# EU         132.555556   0.0  373.0
# OC          58.437500   0.0  254.0
# SA         114.750000  25.0  302.0

# %% [markdown]
# # Titanic (5 points)

# %% [markdown]
# Import titanic passenger data
#
# Note: please upload `titanic2.csv` file using File Explorer tool on your left
#
# **This is different from `titanic.csv` from the previous lab.**
#
# ![image.png](data:image/png;base64,...)

# %%
titanic = pd.read_csv('titanic2.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# Set `PassengerId` as the index
#
# Hint: use `set_index()` method

# %%
titanic = titanic.set_index('PassengerId')
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# Visualize a pie chart representing the gender proportion
#
# example: ![image.png](data:image/png;base64,...)

# %%
sex_count = titanic.Sex.value_counts()
sex_count.plot(kind='pie', autopct='%1.1f%%', explode=(0.05, 0.05), startangle=90)
# Out:
# <AxesSubplot:ylabel='Sex'>

# %% [markdown]
# Visualize a scatter plot with the Fare and the Age, each dot colored by gender
#
# example: ![image.png](data:image/png;base64,...)

# %%
axe = titanic[titanic.Sex=='male'].plot(x='Age', y='Fare', kind='scatter',c='blue', label='Male', grid=True)
titanic[titanic.Sex=='female'].plot(x='Age', y='Fare', kind='scatter',c='green', label='Feale', ax=axe, grid=True, xticks=range(0, 81, 20), yticks=range(0, 601, 100)).legend(bbox_to_anchor=(1.15, 0.5), loc='center')
ax = covid.pivot(columns='location', values='total_cases').plot(ylabel='number of cases', title='Total global COVID cases')
# * ax.legend(bbox_to_anchor=(1.64, 1.03), loc='upper right')  this help move legend

# %%
titanic[titanic.Sex == 'female']
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# ...               ...     ...
# 881                 1       2
# 883                 0       3
# 886                 0       3
# 888                 1       1
# 889                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...                                                        ...     ...   ...
# 881               Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 883                               Dahlberg, Miss. Gerda Ulrika  female  22.0
# 886                       Rice, Mrs. William (Margaret Norton)  female  39.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 9                0      2            347742  11.1333   NaN        S
# 10               1      0            237736  30.0708   NaN        C
# ...            ...    ...               ...      ...   ...      ...
# 881              0      1            230433  26.0000   NaN        S
# 883              0      0              7552  10.5167   NaN        S
# 886              0      5            382652  29.1250   NaN        Q
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 11 columns]

# %% [markdown]
# Visualize a histogram with the Fare
#
# example: ![image.png](data:image/png;base64,...)

# %%
titanic.Fare.plot.hist(bins=60, title='Fare Payed Histogram', grid=True, xlim=[0, 600], edgecolor = "black").set_xlabel('Fare')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/god/Desktop/MyFolder/Programming/Python/Project/Project_university/Y1S2/Lab11/219117_Week11_Pandas.ipynb Cell 47' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/god/Desktop/MyFolder/Programming/Python/Project/Project_university/Y1S2/Lab11/219117_Week11_Pandas.ipynb#ch0000045?line=0'>1</a> titanic.Fare.plot.hist(bins=60, title='Fare Payed Histogram', grid=True, xlim=[0, 600], edgecolor = "black", bg='#ECECF4').set_xlabel('Fare')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py:1346, in PlotAccessor.hist(self, by, bins, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=1285'>1286</a> def hist(self, by=None, bins=10, **kwargs):
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=1286'>1287</a>     """
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=1287'>1288</a>     Draw one histogram of the DataFrame's columns.
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=1288'>1289</a>
#    (...)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=1343'>1344</a>         >>> ax = df.plot.hist(column=["age"], by="gender", figsize=(10, 8))
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=1344'>1345</a>     """
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=1345'>1346</a>     return self(kind="hist", by=by, bins=bins, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=968'>969</a>             label_name = label_kw or data.columns
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=969'>970</a>             data.columns = label_name
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py?line=971'>972</a> return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py?line=68'>69</a>         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py?line=69'>70</a> plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py?line=70'>71</a> plot_obj.generate()
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py?line=71'>72</a> plot_obj.draw()
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py?line=72'>73</a> return plot_obj.result
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:329, in MPLPlot.generate(self)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py?line=326'>327</a> self._compute_plot_data()
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py?line=327'>328</a> self._setup_subplots()
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py?line=328'>329</a> self._make_plot()
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py?line=329'>330</a> self._add_table()
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py?line=330'>331</a> self._make_legend()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py:140, in HistPlot._make_plot(self)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py?line=136'>137</a> if weights is not None and np.ndim(weights) != 1:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py?line=137'>138</a>     kwds["weights"] = weights[:, i]
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py?line=139'>140</a> artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py?line=141'>142</a> # when by is applied, show title for subplots to know which group it is
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py?line=142'>143</a> if self.by is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py:94, in HistPlot._plot(cls, ax, y, style, bins, bottom, column_num, stacking_id, **kwds)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py?line=91'>92</a> bottom = bottom + cls._get_stacked_values(ax, stacking_id, base, kwds["label"])
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py?line=92'>93</a> # ignore style
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py?line=93'>94</a> n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py?line=94'>95</a> cls._update_stacker(ax, stacking_id, n)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/hist.py?line=95'>96</a> return patches
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/__init__.py?line=1408'>1409</a> @functools.wraps(func)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/__init__.py?line=1409'>1410</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/__init__.py?line=1410'>1411</a>     if data is None:
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/__init__.py?line=1411'>1412</a>         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/__init__.py?line=1413'>1414</a>     bound = new_sig.bind(ax, *args, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/__init__.py?line=1414'>1415</a>     auto_label = (bound.arguments.get(label_namer)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/__init__.py?line=1415'>1416</a>                   or bound.kwargs.get(label_namer))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=6788'>6789</a> if patch:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=6789'>6790</a>     p = patch[0]
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=6790'>6791</a>     p.update(kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=6791'>6792</a>     if lbl is not None:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py?line=6792'>6793</a>         p.set_label(lbl)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py:1064, in Artist.update(self, props)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py?line=1061'>1062</a>             func = getattr(self, f"set_{k}", None)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py?line=1062'>1063</a>             if not callable(func):
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py?line=1063'>1064</a>                 raise AttributeError(f"{type(self).__name__!r} object "
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py?line=1064'>1065</a>                                      f"has no property {k!r}")
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py?line=1065'>1066</a>             ret.append(func(v))
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/artist.py?line=1066'>1067</a> if ret:
#
# AttributeError: 'Rectangle' object has no property 'bg'

# %% [markdown]
# Visualize a bar plot representing survival rates in percent grouped by the passenger class

# %%
titanic_pclass = titanic.groupby('Pclass')
mean = titanic_pclass.Survived.mean()*100
mean.plot(kind='bar', label='Survival rates').set_ylabel('Quantity')
# titanic_pclass.Survived.describe()
# Out:
# Text(0, 0.5, 'Quantity')

# %%
mean
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %% [markdown]
# # Apple Stock (10 points)

# %% [markdown]
# Import dataset from `apple_stock_1980_2014.csv`

# %%
apple_stock = pd.read_csv('apple_stock_1980_2014.csv')

# %%
apple_stock
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# Print the type of each data column

# %%
apple_stock.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# Convert the Date column to a datetime type

# %%
apple_stock['Date'] = pd.to_datetime(apple_stock['Date'])
apple_stock
# Out:
#            Date   Open   High    Low  Close     Volume  Adj Close
# 0    2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1    2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2    2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3    2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4    2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...         ...    ...    ...    ...    ...        ...        ...
# 8460 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# Set the date as the index

# %% [markdown]
# Check if there is any duplicate dates

# %%
apple_stock.set_index('Date', inplace=True)
apple_stock
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]

# %% [markdown]
# Currently, the index is from the most recent date. Sort the entries so that the oldest date comes first.

# %%
apple_stock = apple_stock.sort_index()
apple_stock
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# ...           ...    ...    ...    ...        ...        ...
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
# [8465 rows x 6 columns]

# %% [markdown]
# Find the last business day of each month using `resample('BM')`

# %%
apple_stock.resample('BM').mean()
# Out:
#                   Open        High         Low       Close        Volume  \
# Date
# 1980-12-31   30.481538   30.567692   30.443077   30.443077  2.586252e+07
# 1981-01-30   31.754762   31.826667   31.654762   31.654762  7.249867e+06
# 1981-02-27   26.480000   26.572105   26.407895   26.407895  4.231832e+06
# 1981-03-31   24.937727   25.016818   24.836364   24.836364  7.962691e+06
# 1981-04-30   27.286667   27.368095   27.227143   27.227143  6.392000e+06
# ...                ...         ...         ...         ...           ...
# 2014-03-31  533.593333  536.453810  530.070952  533.214286  5.954403e+07
# 2014-04-30  540.081905  544.349048  536.262381  541.074286  7.660787e+07
# 2014-05-30  601.301905  606.372857  598.332857  603.195714  6.828177e+07
# 2014-06-30  222.360000  224.084286  220.735714  222.658095  5.745506e+07
# 2014-07-31   94.294000   95.004000   93.488000   94.470000  4.218366e+07
#
#             Adj Close
# Date
# 1980-12-31   0.473077
# 1981-01-30   0.493810
# 1981-02-27   0.411053
# 1981-03-31   0.387727
# 1981-04-30   0.423333
# ...               ...
# 2014-03-31  75.750000
# 2014-04-30  76.867143
# 2014-05-30  86.058571
# 2014-06-30  91.885714
# 2014-07-31  94.470000
#
# [404 rows x 6 columns]

# %% [markdown]
# Compute the difference in days between the first and the last day

# %%
diff = apple_stock.iloc[-1].name - apple_stock.iloc[0].name
diff.days
# Out:
# 12261

# %% [markdown]
# Compute the number of months in the data we have

# %%
len(apple_stock.resample('M'))
# Out:
# 404

# %% [markdown]
# Plot the 'Adj Close' value.

# %%
apple_stock.groupby('Adj Close').mean()
# Out:
#                  Open        High         Low       Close        Volume
# Adj Close
# 0.17        11.120000   11.120000   11.000000   11.000000  4.108160e+07
# 0.18        11.532500   11.627500   11.500000   11.500000  1.936760e+07
# 0.19        12.373333   12.458333   12.310000   12.310000  1.942920e+07
# 0.20        13.026842   13.072105   12.941579   12.941579  1.181924e+07
# 0.21        13.481667   13.590556   13.446667   13.446667  1.178924e+07
# ...               ...         ...         ...         ...           ...
# 95.96      699.350000  699.800000  694.610000  699.780000  9.950780e+07
# 95.97       94.140000   95.990000   94.100000   95.970000  5.630540e+07
# 96.00      702.410000  705.070000  699.360000  700.090000  1.428973e+08
# 96.25      699.880000  702.330000  696.420000  701.910000  9.337580e+07
# 96.28      700.260000  703.990000  699.570000  702.100000  8.171870e+07
#
# [2325 rows x 5 columns]
