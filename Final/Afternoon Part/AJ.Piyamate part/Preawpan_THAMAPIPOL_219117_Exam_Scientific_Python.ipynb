# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Restaurant Tipping

# %% [markdown]
# ## 1) Import the dataset (1 point)
# Import restaurant tipping record from https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv
#
# Description: `total_bill` and `tip` are in USD ($) amount representing restaurant bill and the customer tip, `size` represents the number of persons in that bill
#
# Hint: `pd.read_csv(URL HERE)`

# %%
restaurant = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv')

# %%
restaurant
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# ## 2) Deleting a column (1 point)
# Delete the Unnamed 0 column
#
# Hint: `del dataFrame['column']`

# %%
del restaurant['Unnamed: 0']
restaurant
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## 3) Histogram (2 points)
# Plot the total_bill column histogram (x-axis: bill amount, y-axis: number of bills), set labels for x & y axes and plot title appropriately
#
# Hint:
# *   `fig = dataFrame['column'].hist()`
# *   `fig.set_xlabel()`
# *   `fig.set_ylabel()`

# %%
fig = restaurant.total_bill.hist()
fig.set_xlabel('bill amount')
fig.set_ylabel('number of bills')
fig.set_title('Histogram of bill amount')
# Out:
# Text(0.5, 1.0, 'Histogram of bill amount')

# %% [markdown]
# ## 4) Correlation via scatter plot (2 points)
# Create a scatter plot presenting the relationship between total_bill (x-axis) and tip (y-axis). Set labels for x & y axes and plot title appropriately.

# %%
restaurant.plot('total_bill', 'tip', kind='scatter', xlabel='total bill', ylabel='tip amount', title='Scatter plot of total bill and tip amount')
# Out:
# <AxesSubplot:title={'center':'Scatter plot of total bill and tip amount'}, xlabel='total bill', ylabel='tip amount'>

# %% [markdown]
# ## 5) Tip vs weekday (2 points)
# Create a boxplot with 4 boxes showing amount of tip per weekday [Sat, Sun, Thur, Fri]. Set labels for x & y axes and plot title appropriately.
#
# Hint: combine `groupby()` with `boxplot()`

# %%
restaurant
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
ax = restaurant.groupby('day').boxplot('day', 'tip') # unsure
ax.set_ylabel('tip amount')
# Out:
# Text(0, 0.5, 'tip amount')

# %% [markdown]
# ## 6) Tip vs time (3 points)
# Create two histograms of the tip value based for Dinner and Lunch. They must be side by side. Set labels for x & y axes and plot title appropriately.
#
# Hint:
# *   `fig, ax = plt.subplots(1, 2)`
# *   `hist(ax=ax[0])`
# *   `fig.suptitle()`
# *   `ax[0].set_title()`

# %%
dinner
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
dinner = restaurant[restaurant.time == 'Dinner']
launch = restaurant[restaurant.time == 'Lunch']
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

dinner.hist(ax=axes[0], column='tip')
launch.hist(ax=axes[1], column='tip')
axes[0].set_title('Dinner')
axes[1].set_title('Lunch')

time_list = ['Dinner', 'Lunch']

for i in range(2):
    axes[i].set_xlabel(f'tip amount for {time_list[i]}')
    axes[i].set_ylabel('number of bills')

fig.suptitle('Histogram of tip amount')
# Out:
# Text(0.5, 0.98, 'Histogram of tip amount')

# %% [markdown]
# # COVID-19 cases

# %% [markdown]
# ## 1) COVID cases data import from JHU (1 point)

# %% [markdown]
# Import worldwide **daily** COVID dataset provided by Johns Hopkins University
# from https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/jhu/full_data.csv

# %%
covid = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/jhu/full_data.csv', date_parser='date')

covid
# Out:
#               date     location  new_cases  new_deaths  total_cases  \
# 0       2020-02-24  Afghanistan        5.0         NaN          5.0
# 1       2020-02-25  Afghanistan        0.0         NaN          5.0
# 2       2020-02-26  Afghanistan        0.0         NaN          5.0
# 3       2020-02-27  Afghanistan        0.0         NaN          5.0
# 4       2020-02-28  Afghanistan        0.0         NaN          5.0
# ...            ...          ...        ...         ...          ...
# 176520  2022-04-28     Zimbabwe       55.0         0.0     247784.0
# 176521  2022-04-29     Zimbabwe       58.0         0.0     247842.0
# 176522  2022-04-30     Zimbabwe       33.0         0.0     247875.0
# 176523  2022-05-01     Zimbabwe       36.0         0.0     247911.0
# 176524  2022-05-02     Zimbabwe       24.0         1.0     247935.0
#
#         total_deaths  weekly_cases  weekly_deaths  biweekly_cases  \
# 0                NaN           NaN            NaN             NaN
# ...

# %% [markdown]
# ## 2) COVID cases in Thailand (2 points)

# %% [markdown]
# Plot the number of total cases for Thailand over time (x-axis: date, y-axis: number of cases **in million**) using **area plot**, set labels for x & y axes and plot title appropriately
#
# Hint: `pivot()`, `dataFrame.column.plot.area()`

# %%
covid.pivot('date', 'location', 'total_cases')['Thailand'].plot.area(ylabel='total cases', title='Total cases of covid-19 in Thailand')
# Out:
# <AxesSubplot:title={'center':'Total cases of covid-19 in Thailand'}, xlabel='date', ylabel='total cases'>

# %% [markdown]
# ## 3) COVID cases globally (1 point)

# %% [markdown]
# Plot the number total cases globally over time (x-axis: date, y-axis: number of cases **in billion**) using **area plot**, set labels for x & y axes and plot title appropriately

# %%
covid.pivot('date', 'location', 'total_cases')['World'].plot.area(ylabel='total cases', title='Total global cases of covid-19')
# Out:
# <AxesSubplot:title={'center':'Total global cases of covid-19'}, xlabel='date', ylabel='total cases'>

# %% [markdown]
# ## 4) COVID cases comparison #1 (4 points)

# %% [markdown]
# Plot number of cases over time for the following countries (x-axis: date, y-axis: number of cases **in million**) using **line plot**
# *   Thailand
# *   United Kingdom
# *   China
# *   United States
# *   Singapore
# *   New Zealand
#
# Conditions:
# *   Put all 4 data lines in one plot
# *   Show data legend
# *   Use log scale for y-axis
# *   Set figure size to 20 x 10 inch
# *   Set labels for x & y axes and plot title appropriately
# *   Show gridlines
#
# Hints:
# *   `plt.legend()`
# *   `plot(figsize=(20,10, logy=True)`
# *   `plot.grid(True)`

# %%
covid_copy = covid.copy()
covid_copy['total_cases'] /= 1e6
data = covid_copy.pivot('date', 'location', 'total_cases')[['Thailand', 'United Kingdom', 'China', 'United States']]
data.plot(figsize=(20, 10), logy=True, grid=True, ylabel='number of cases in million', title='number of COVID cases over time at Thailand, United Kingdom, China and United States')
# Out:
# <AxesSubplot:title={'center':'number of COVID cases over time at Thailand, United Kingdom, China and United States'}, xlabel='date', ylabel='number of cases in million'>

# %% [markdown]
# ## 5) COVID cases comparison #2 (3 points)

# %% [markdown]
# Plot the same data above, but convert the data in y axis from `number of cases` to `per million population`. Use population data provided by this file: https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/jhu/locations.csv

# %%
population = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/jhu/locations.csv')
population
# Out:
#         Country/Region           location continent  population_year  \
# 0          Afghanistan        Afghanistan      Asia           2021.0
# 1              Albania            Albania    Europe           2021.0
# 2              Algeria            Algeria    Africa           2021.0
# 3              Andorra            Andorra    Europe           2021.0
# 4               Angola             Angola    Africa           2021.0
# ..                 ...                ...       ...              ...
# 211            Vietnam            Vietnam      Asia           2021.0
# 212  Wallis and Futuna  Wallis and Futuna   Oceania           2021.0
# 213              Yemen              Yemen      Asia           2021.0
# 214             Zambia             Zambia    Africa           2021.0
# 215           Zimbabwe           Zimbabwe    Africa           2021.0
#
#      population
# 0    39835428.0
# 1     2872934.0
# 2    44616626.0
# 3       77354.0
# 4    33933611.0
# ..          ...
# ...

# %%
merged_data = covid.merge(population, on='location')
# merged_data.set_index('date', inplace=True)

# %%
merged_data['cases_per_million_population'] = merged_data['total_cases'] / (merged_data['population'] / 1e6)
merged_data
# Out:
#               date     location  new_cases  new_deaths  total_cases  \
# 0       2020-02-24  Afghanistan        5.0         NaN          5.0
# 1       2020-02-25  Afghanistan        0.0         NaN          5.0
# 2       2020-02-26  Afghanistan        0.0         NaN          5.0
# 3       2020-02-27  Afghanistan        0.0         NaN          5.0
# 4       2020-02-28  Afghanistan        0.0         NaN          5.0
# ...            ...          ...        ...         ...          ...
# 166626  2022-04-28     Zimbabwe       55.0         0.0     247784.0
# 166627  2022-04-29     Zimbabwe       58.0         0.0     247842.0
# 166628  2022-04-30     Zimbabwe       33.0         0.0     247875.0
# 166629  2022-05-01     Zimbabwe       36.0         0.0     247911.0
# 166630  2022-05-02     Zimbabwe       24.0         1.0     247935.0
#
#         total_deaths  weekly_cases  weekly_deaths  biweekly_cases  \
# 0                NaN           NaN            NaN             NaN
# ...

# %%
data = merged_data.pivot('date', 'location', 'cases_per_million_population')[['Thailand', 'United Kingdom', 'China', 'United States']]
data.plot(figsize=(20, 10), logy=True, grid=True, ylabel='number of cases per million population', title='number of COVID cases per million population over time at Thailand, United Kingdom, China and United States')
# Out:
# <AxesSubplot:title={'center':'number of COVID cases per million population over time at Thailand, United Kingdom, China and United States'}, xlabel='date', ylabel='number of cases per million population'>

# %% [markdown]
# ## 6) COVID new cases per day comparison (3 points)

# %% [markdown]
# Using the same format as above, plot `number of new cases per day` in `per million population`. Because the daily data is somewhat noisy, use a moving average of 14-day period to smoothen the data.
#
# Hint: `covid_new_cases_percent['Thailand'].rolling(window=14).mean().plot()`

# %%
merged_data['new_cases_per_day_million_population'] = merged_data['new_cases'] / (merged_data['population'] / 1e6)

merged_data
# Out:
#               date     location  new_cases  new_deaths  total_cases  \
# 0       2020-02-24  Afghanistan        5.0         NaN          5.0
# 1       2020-02-25  Afghanistan        0.0         NaN          5.0
# 2       2020-02-26  Afghanistan        0.0         NaN          5.0
# 3       2020-02-27  Afghanistan        0.0         NaN          5.0
# 4       2020-02-28  Afghanistan        0.0         NaN          5.0
# ...            ...          ...        ...         ...          ...
# 166626  2022-04-28     Zimbabwe       55.0         0.0     247784.0
# 166627  2022-04-29     Zimbabwe       58.0         0.0     247842.0
# 166628  2022-04-30     Zimbabwe       33.0         0.0     247875.0
# 166629  2022-05-01     Zimbabwe       36.0         0.0     247911.0
# 166630  2022-05-02     Zimbabwe       24.0         1.0     247935.0
#
#         total_deaths  weekly_cases  weekly_deaths  biweekly_cases  \
# 0                NaN           NaN            NaN             NaN
# ...

# %%
data = merged_data.pivot('date', 'location', 'new_cases_per_day_million_population')[['Thailand', 'United Kingdom', 'China', 'United States']].rolling(window=14).mean()
data.plot(figsize=(20, 10), logy=True, grid=True, ylabel='14 day average of new cases per day permillion population', title='14 days average of number of new COVID cases per day over time at Thailand, United Kingdom, China and United States')
# Out:
# <AxesSubplot:title={'center':'14 days average of number of new COVID cases per day over time at Thailand, United Kingdom, China and United States'}, xlabel='date', ylabel='14 day average of new cases per day permillion population'>
